# %%
# import library
import seaborn
# canvas (Baloon board)
seaborn.set(style="whitegrid")
#
boat = seaborn.load_dataset("titanic")

seaborn.boxplot(x="class", 
                y="fare", 
                data=boat)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn
seaborn.set(style="whitegrid")

tip = seaborn.load_dataset("tips")
tip
seaborn.boxplot(x="day", y="tip", data=tip, saturation=1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn
import pandas as pf
import numpy as np
seaborn.set(style="whitegrid")

tip = seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn
seaborn.set(style="whitegrid")

tip = seaborn.load_dataset("tips")
tip
seaborn.boxplot(x=tip["size"])
# Out:
# <Axes: xlabel='size'>

# %%
import seaborn as sns
sns.set(style="whitegrid")

tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", hue="smoker", data=tip, 
           palette="Set2", dodge=True,)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set(style="whitegrid")

tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="day", data=tip, saturation=1, color="#34ebe2")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set(style="whitegrid")

tip = sns.load_dataset("tips")
tip
sns.boxplot(x="tip", y="", data=tip, saturation=1, color="#34ebe2")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

boat = sns.load_dataset("titanic")
boat.head(5)

sns.boxplot(x="sex",
            y="fare",
            data=boat)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxplot(x="survived",
            y="age", showmeans=True,
            data=boat)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

boat = sns.load_dataset("titanic")
sns.boxplot(x="survived",
            y="age", showmeans=True,
            meanprops = {"marker":"*",
                         "markersize":"15",
                         "markeredgecolor":"yellow"},
            data=boat)
plt.xlabel("how many survived", size=10, weight="bold"),
plt.ylabel("Age(years)", size=10, weight="bold"),
plt.title("Box plot of titanic", size=13, weight="bold")
plt.show()
